# %%
import pyupbit as upbit
import pandas as pd
import matplotlib.pyplot as plt
import csv
import numpy as np

# %%
upbit.get_tickers(fiat='KRW')
# Out:
# ['KRW-BTC',
#  'KRW-ETH',
#  'KRW-NEO',
#  'KRW-MTL',
#  'KRW-LTC',
#  'KRW-XRP',
#  'KRW-ETC',
#  'KRW-OMG',
#  'KRW-SNT',
#  'KRW-WAVES',
#  'KRW-XEM',
#  'KRW-QTUM',
#  'KRW-LSK',
#  'KRW-STEEM',
#  'KRW-XLM',
#  'KRW-ARDR',
#  'KRW-ARK',
#  'KRW-STORJ',
#  'KRW-GRS',
#  'KRW-REP',
#  'KRW-ADA',
#  'KRW-SBD',
#  'KRW-POWR',
#  'KRW-BTG',
#  'KRW-ICX',
#  'KRW-EOS',
#  'KRW-TRX',
#  'KRW-SC',
#  'KRW-ONT',
#  'KRW-ZIL',
#  'KRW-POLY',
#  'KRW-ZRX',
#  'KRW-LOOM',
#  'KRW-BCH',
#  'KRW-BAT',
#  'KRW-IOST',
#  'KRW-RFR',
#  'KRW-CVC',
#  'KRW-IQ',
#  'KRW-IOTA',
#  'KRW-MFT',
#  'KRW-ONG',
#  'KRW-GAS',
#  'KRW-UPP',
#  'KRW-ELF',
#  'KRW-KNC',
#  'KRW-BSV',
#  'KRW-THETA',
#  'KRW-QKC',
#  'KRW-BTT',
#  'KRW-MOC',
#  'KRW-ENJ',
#  'KRW-TFUEL',
#  'KRW-MANA',
#  'KRW-ANKR',
#  'KRW-AERGO',
#  'KRW-ATOM',
#  'KRW-TT',
#  'KRW-CRE',
#  'KRW-MBL',
#  'KRW-WAXP',
#  'KRW-HBAR',
#  'KRW-MED',
#  'KRW-MLK',
#  'KRW-STPT',
#  'KRW-ORBS',
#  'KRW-VET',
#  'KRW-CHZ',
#  'KRW-STMX',
# ...

# %%
upbit.get_current_price(["KRW-BTC", "KRW-ETH", "KRW-XRP"])
# Out:
# {'KRW-BTC': 48868000.0, 'KRW-ETH': 3597000.0, 'KRW-XRP': 790.0}

# %%
ticker = 'KRW-BTC'
##interval -> month, week, day, minute(1, 3, 5, 10, 15, 30, 60, 240)
interval = 'day'
to = '2022-05-04'
count = 30
btcData = upbit.get_ohlcv(ticker=ticker, interval=interval, to=to, count = count)
btcCsv = pd.DataFrame(btcData)
##btcCsv.to_csv("BTC_Day.csv", index = True)

# %%
ticker = 'KRW-CRO'
interval = 'day'
to = '2022-05-04'
count = 30
croData = upbit.get_ohlcv(ticker=ticker, interval=interval, to=to, count = count)
croCsv = pd.DataFrame(croData)
##croCsv.to_csv("CRO_Day.csv", index=True)

# %%
ticker = 'KRW-XRP'
interval = 'day'
to = '2022-05-04'
count = 30
xrpData = upbit.get_ohlcv(ticker=ticker, interval=interval, to=to, count = count)
xrpCsv = pd.DataFrame(xrpData)
##xrpCsv.to_csv("XRP_Day.csv", index=True)

# %%
ticker = 'KRW-ORBS'
interval = 'day'
to = '2022-05-04'
count = 30
orbsData = upbit.get_ohlcv(ticker=ticker, interval=interval, to=to, count = count)
orbsCsv = pd.DataFrame(orbsData)
##orbsCsv.to_csv("ORBS_Day.csv", index=True)

# %%
btcMade = pd.read_csv('C:\\Users\\YONSAI\\Documents\\GitHub\\Yonsai_IT_Academy\\CoinProject\\BTC_Day.csv')
btcVol = btcMade[['date', 'volume']]
btcMade = btcMade[['date','close']]
btcMade.plot()
btcVol.plot()
# Out:
# <AxesSubplot:>

# %%
btc_X = btcMade[['date']]
btc_Y = btcMade[['close']]

# %%
croMade = pd.read_csv('C:\\Users\\YONSAI\\Documents\\GitHub\\Yonsai_IT_Academy\\CoinProject\\CRO_Day.csv')
croVol = croMade[['date', 'volume']]
croMade = croMade[['date','close']]
croMade.plot()
croVol.plot()
# Out:
# <AxesSubplot:>

# %%
xrpMade = pd.read_csv('C:\\Users\\YONSAI\\Documents\\GitHub\\Yonsai_IT_Academy\\CoinProject\\XRP_Day.csv')
xrpVol = xrpMade[['date', 'volume']]
xrpMade = xrpMade[['date','close']]
xrpMade.plot()
xrpVol.plot()
# Out:
# <AxesSubplot:>

# %%
orbsMade = pd.read_csv('C:\\Users\\YONSAI\\Documents\\GitHub\\Yonsai_IT_Academy\\CoinProject\\ORBS_Day.csv')
orbsVol = orbsMade[['date','volume']]
orbsMade = orbsMade[['date','close']]
orbsMade.plot()
orbsVol.plot()
# Out:
# <AxesSubplot:>
